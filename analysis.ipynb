# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import lines
from matplotlib import patches
from matplotlib.patheffects import withStroke

BLUE = "#0D0887"
RED = "#FCD025"

# %%
fig, ax = plt.subplots(figsize=(5 / 3 + 0.25, 5))

barWidth = 0.25
max_y = 250
y_tick_difference = 50
# set heights of bars
bars1 = [248]
bars2 = [115]

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

# Make the plot
plt.bar(r1, bars1, color=BLUE, width=barWidth, edgecolor='white', label='Failure')
plt.bar(r2, bars2, color=RED, width=barWidth, edgecolor='white', label='No Failure')
ax.yaxis.set_ticks([i * y_tick_difference for i in range(0, max_y)])
ax.yaxis.set_ticklabels([i * y_tick_difference for i in range(0, max_y)], size=16, fontfamily="Econ Sans Cnd",
                        fontweight=100)
ax.yaxis.set_tick_params(labelbottom=False, labeltop=True, length=0)

ax.set_ylim((0, max_y))

# Set whether axis ticks and gridlines are above or below most artists.
ax.set_axisbelow(True)
ax.grid(axis="y", color="#A8BAC4", lw=1.2)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["bottom"].set_lw(1.5)
# This capstyle determines the lines don't go beyond the limit we specified
# see: https://matplotlib.org/stable/api/_enums_api.html?highlight=capstyle#matplotlib._enums.CapStyle
ax.spines["left"].set_capstyle("butt")

# Hide y labels
#ax.yaxis.set_visible(False)

# Add xticks on the middle of the group bars
plt.xlabel('Variable', fontweight='bold')
plt.xticks([r + barWidth / 2 for r in range(len(bars1))], ['Categories'])

# Create legend & Show graphic
fig.subplots_adjust(left=0.005, right=1, top=0.8, bottom=0.1)

plt.legend(["Failure", "No Failure"], bbox_to_anchor=([1.075, 1.2, 0, 0]), ncol=1, frameon=False, fontsize=12.5)
fig.set_facecolor("white")
plt.savefig("figures/eda_categories.pdf", bbox_inches="tight")
plt.show()
# Out:
# findfont: Font family ['Econ Sans Cnd'] not found. Falling back to DejaVu Sans.

# %%
fig, ax = plt.subplots(figsize=(5 / 3 + 0.25, 5))

barWidth = 0.25
max_y = 7000
y_tick_difference = 1000
# set heights of bars
bars1 = [6763]
bars2 = [6763]

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

# Make the plot
plt.bar(r1, bars1, color=BLUE, width=barWidth, edgecolor='white', label='Failure')
plt.bar(r2, bars2, color=RED, width=barWidth, edgecolor='white', label='No Failure')
ax.yaxis.set_ticks([i * y_tick_difference for i in range(0, max_y)])
ax.yaxis.set_ticklabels([i * y_tick_difference for i in range(0, max_y)], size=16, fontfamily="Econ Sans Cnd",
                        fontweight=100)
ax.yaxis.set_tick_params(labelbottom=False, labeltop=True, length=0)

ax.set_ylim((0, max_y))

# Set whether axis ticks and gridlines are above or below most artists.
ax.set_axisbelow(True)
ax.grid(axis="y", color="#A8BAC4", lw=1.2)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["bottom"].set_lw(1.5)
# This capstyle determines the lines don't go beyond the limit we specified
# see: https://matplotlib.org/stable/api/_enums_api.html?highlight=capstyle#matplotlib._enums.CapStyle
ax.spines["left"].set_capstyle("butt")

# Hide y labels
#ax.yaxis.set_visible(False)

# Add xticks on the middle of the group bars
plt.xlabel('Variable', fontweight='bold')
plt.xticks([r + barWidth / 2 for r in range(len(bars1))], ['Categories'])

# Create legend & Show graphic
fig.subplots_adjust(left=0.005, right=1, top=0.8, bottom=0.1)

plt.legend(["Failure", "No Failure"], bbox_to_anchor=([1.075, 1.2, 0, 0]), ncol=1, frameon=False, fontsize=12.5)
fig.set_facecolor("white")
plt.savefig("figures/eda_categories_rebalanced.pdf", bbox_inches="tight")
plt.show()

# %%
matlab_training_time_ms = 0.08064 * 1000
python_training_time_ms = 0.24641986608505248 * 1000
training_times = [matlab_training_time_ms, python_training_time_ms]
names = ["Matlab", "Python"]

# The positions for the bars
# This allows us to determine exactly where each bar is located
y = [i * 0.9 for i in range(len(names))]

fig, ax = plt.subplots(figsize=(8, 3))

ax.barh(y, training_times, height=0.55, align="edge", color=BLUE)
max_x = 250
x_tick_difference = max_x / 5
ax.xaxis.set_ticks([i * x_tick_difference for i in range(0, max_x)])
ax.xaxis.set_ticklabels([i * x_tick_difference for i in range(0, max_x)], size=16, fontfamily="Econ Sans Cnd",
                        fontweight=100)
ax.xaxis.set_tick_params(labelbottom=False, labeltop=True, length=0)

ax.set_xlim((0, max_x))
ax.set_ylim((0, len(names) * 0.9 - 0.2))

# Set whether axis ticks and gridlines are above or below most artists.
ax.set_axisbelow(True)
ax.grid(axis="x", color="#A8BAC4", lw=1.2)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_lw(1.5)
# This capstyle determines the lines don't go beyond the limit we specified
# see: https://matplotlib.org/stable/api/_enums_api.html?highlight=capstyle#matplotlib._enums.CapStyle
ax.spines["left"].set_capstyle("butt")

# Hide y labels
ax.yaxis.set_visible(False)

PAD = 0.3
for name, count, y_pos in zip(names, training_times, y):
    x = 0
    color = "white"
    path_effects = None
    if count < 5:
        x = count
        color = BLUE
        path_effects = [withStroke(linewidth=6, foreground="white")]

    ax.text(
        x + PAD, y_pos + 0.5 / 2, name,
        color=color, fontfamily="Econ Sans Cnd", fontsize=15, va="center",
        path_effects=path_effects
    )

fig.subplots_adjust(left=0.005, right=1, top=0.8, bottom=0.1)

# Add title
fig.text(
    0, 1.02, "Training Time (ms)",
    fontsize=20, fontweight="bold", fontfamily="Econ Sans Cnd"
)
# Add subtitle
fig.text(
    0, 0.935, "Python vs Matlab, 2 Hidden Neurons, 50 Epochs",
    fontsize=18, fontfamily="Econ Sans Cnd"
)

# Set facecolor, useful when saving as .png
fig.set_facecolor("white")
plt.savefig("figures/training_time.pdf", bbox_inches="tight")
plt.show()
# Out:
# findfont: Font family ['Econ Sans Cnd'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Econ Sans Cnd'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Econ Sans Cnd'] not found. Falling back to DejaVu Sans.

# %%
epochs_tries = [10, 25, 50, 100, 200]
python_accuracy = [20.7, 96.6, 41.16666666666667, 33.46666666666667, 41.6]
matlab_accuracy = [79.8667, 100.0000, 91.0000, 59.4333, 69.3667]

fig, ax = plt.subplots(figsize=(7, 5.1))
plt.plot(epochs_tries, python_accuracy, 'o', label="Python",
         color=BLUE)
plt.plot(epochs_tries, matlab_accuracy, 'o', label="Matlab",
         color=RED)

# Set whether axis ticks and gridlines are above or below most artists.
ax.set_axisbelow(True)
ax.grid(axis="y", color="#A8BAC4", lw=1.2)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_visible(False)
# This capstyle determines the lines don't go beyond the limit we specified
# see: https://matplotlib.org/stable/api/_enums_api.html?highlight=capstyle#matplotlib._enums.CapStyle
#ax.spines["left"].set_capstyle("butt")
plt.legend(["Python", "Matlab"], bbox_to_anchor=([1.02, 1.274, 0, 0]), ncol=1, frameon=False, fontsize=12.5)

fig.subplots_adjust(left=0.005, right=1, top=0.8, bottom=0.1)

# Add title
fig.text(
    0, 0.932, "Epochs vs Accuracy",
    fontsize=20, fontweight="bold", fontfamily="Econ Sans Cnd"
)
# Add subtitle
fig.text(
    0, 0.875, "2 Hidden Neurons, Learning Rate 0.3",
    fontsize=18, fontfamily="Econ Sans Cnd"
)

ax.yaxis.set_ticks([20, 30, 40, 50, 60, 70, 80, 90, 100])
ax.yaxis.set_ticklabels([20, 30, 40, 50, 60, 70, 80, 90, 100], size=16, fontfamily="Econ Sans Cnd", fontweight=100)
ax.yaxis.set_tick_params(labelbottom=True, labeltop=False, length=0)

ax.xaxis.set_ticks([25, 50, 75, 100, 125, 150, 175, 200, 225, 250])
ax.xaxis.set_ticklabels([25, 50, 75, 100, 125, 150, 175, 200, 225, 250], size=16, fontfamily="Econ Sans Cnd",
                        fontweight=100)
ax.xaxis.set_tick_params(labelbottom=True, labeltop=False)
plt.ylim(15, 103)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.savefig("figures/epochs_vs_accuracy.pdf", bbox_inches="tight")
plt.show()
